# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)
DATA_PATH = "dataset/2019-Nov.csv" 
DATA_PATH_2 = "dataset/2019-Oct.csv"

# %%
df = pd.read_csv(
    DATA_PATH,
    nrows=1_000_000
)
df
# Out:
#                      event_time event_type  product_id          category_id                     category_code  \
# 0       2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655            electronics.smartphone
# 1       2019-11-01 00:00:00 UTC       view     5000088  2053013566100866035         appliances.sewing_machine
# 2       2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655                               NaN
# 3       2019-11-01 00:00:01 UTC       view     3601530  2053013563810775923         appliances.kitchen.washer
# 4       2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655            electronics.smartphone
# ...                         ...        ...         ...                  ...                               ...
# 999995  2019-11-01 15:32:09 UTC       view    11400039  2053013558458843721                               NaN
# ...

# %%
df.shape
# Out:
# (1000000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   event_time     1000000 non-null  object
#  1   event_type     1000000 non-null  object
#  2   product_id     1000000 non-null  int64
#  3   category_id    1000000 non-null  int64
#  4   category_code  683023 non-null   object
#  5   brand          852803 non-null   object
#  6   price          1000000 non-null  float64
#  7   user_id        1000000 non-null  int64
#  8   user_session   1000000 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 68.7+ MB

# %%
distinct_values = df['event_type'].unique()
print(distinct_values)
# Out:
# ['view' 'cart' 'purchase']

# %%
distinct_values = df['brand'].unique()
print(distinct_values[:20])
# Out:
# ['xiaomi' 'janome' 'creed' 'lg' 'hp' 'rondell' 'michelin' 'apple' nan
#  'samsung' 'huawei' 'yokohama' 'trussardi' 'eveline' 'acer' 'asus' 'nika'
#  'matrix' 'redmond' 'tomfarr']

# %%
distinct_values = df['category_code'].unique()
print(distinct_values[:20])
# Out:
# ['electronics.smartphone' 'appliances.sewing_machine' nan
#  'appliances.kitchen.washer' 'computers.notebook'
#  'furniture.living_room.sofa' 'appliances.kitchen.refrigerators'
#  'furniture.kitchen.chair' 'appliances.kitchen.dishwasher'
#  'electronics.audio.headphone' 'appliances.environment.vacuum'
#  'appliances.environment.water_heater' 'electronics.camera.video'
#  'electronics.clocks' 'electronics.video.tv' 'apparel.tshirt'
#  'apparel.jeans' 'construction.tools.drill' 'auto.accessories.compressor'
#  'computers.components.motherboard']

# %%
nb_users = df['product_id'].nunique()
print("Nombre de produits distincts :", nb_users)
# Out:
# Nombre de produits distincts : 66001

# %%
nb_products = df['user_id'].nunique()
print("Nombre de users distincts :", nb_products)
# Out:
# Nombre de users distincts : 170337

# %%
df.select("event_time").show(5)
